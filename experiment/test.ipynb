# %%
import os 
from pathlib import Path

# %%
file_path = 'experiemnt\test.ipynb' 
path = Path(file_path) 
path
# Out:
# WindowsPath('experiemnt\test.ipynb')

# %%
file_file_name = os.path.split(path)  
file_file_name
# Out:
# ('', 'experiemnt\test.ipynb')
